# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('quanTri.csv')
df
# Out:
#                    Kinh te vi mo Toan cao cap C1  Marketing can ban  \
# 0    Diem tong ket          7,80            7,30               7,00
# 1    Diem tong ket          6,60            6,50               6,30
# 2    Diem tong ket          8,90            8,20               7,90
# 3    Diem tong ket          6,30            6,00               6,40
# 4    Diem tong ket          8,70            9,20               7,70
# ..             ...           ...             ...                ...
# 118  Diem tong ket          4,80            6,60               8,90
# 119  Diem tong ket          9,40            9,20               7,20
# 120  Diem tong ket          7,60            7,80               7,10
# 121  Diem tong ket          5,40            5,00               7,40
# 122  Diem tong ket          4,60            7,30               6,60
#
#     Ky nang giao tiep Giao duc quoc phong Ky nang ban hang  \
# 0                9,20                8,00             8,00
# 1                9,30                7,00             7,60
# 2                9,70                7,00             7,90
# 3                9,30                7,00             6,50
# 4                9,70                7,00             7,90
# ..                ...                 ...              ...
# 118              5,80                7,00              NaN
# 119              5,90                7,00              NaN
# 120              7,30                8,00              NaN
# 121              6,10                5,40              NaN
# 122              6,50                7,00              NaN
#
#     Nhap mon nganh quan tri  Tin hoc MOS 1 (Windows, Word)  \
# 0                      8,00                           7,70
# 1                      7,50                           6,80
# 2                      8,40                           9,30
# 3                      7,00                           5,50
# 4                      7,40                           9,30
# ..                      ...                            ...
# 118                    7,50                           4,80
# 119                    8,30                           8,20
# 120                    9,20                           9,00
# 121                    7,40                           6,00
# 122                    7,40                           6,70
#
#      Sinh hoat dau khoa  ... Hanh vi to chuc Quan tri rui ro trong kinh doanh  \
# 0                   NaN  ...             NaN                              NaN
# 1                   NaN  ...             NaN                              NaN
# 2                   NaN  ...             NaN                              NaN
# 3                   NaN  ...             NaN                              NaN
# 4                   NaN  ...             NaN                              NaN
# ..                  ...  ...             ...                              ...
# 118                 NaN  ...            7,40                             7,00
# 119                 NaN  ...            8,00                             7,00
# 120                 NaN  ...            8,00                             6,80
# 121                 NaN  ...            6,70                             9,40
# 122                 NaN  ...            9,00                             6,80
#
#     Quan tri Logistics Quan tri kinh doanh quoc te  \
# 0                  NaN                         NaN
# 1                  NaN                         NaN
# 2                  NaN                         NaN
# 3                  NaN                         NaN
# 4                  NaN                         NaN
# ..                 ...                         ...
# 118               9,00                        7,80
# 119               6,70                        5,70
# 120               9,00                        7,70
# 121               8,40                        9,20
# 122               8,30                        4,40
#
#      Module 2: Kinh doanh xuat nhap khau Tam ly hoc dai cuong  \
# 0                                    NaN                  NaN
# 1                                    NaN                  NaN
# 2                                    NaN                  NaN
# 3                                    NaN                  NaN
# 4                                    NaN                  NaN
# ..                                   ...                  ...
# 118                                 8,00                 6,70
# 119                                 9,00                 8,20
# 120                                 8,20                 7,70
# 121                                 8,00                 7,10
# 122                                 8,60                 8,60
#
#     Van tai, bao hiem van tai quoc te  Logistics Trung binh tich luy  \
# 0                                 NaN        NaN                7,70
# 1                                 NaN        NaN                7,35
# 2                                 NaN        NaN                8,30
# 3                                 NaN        NaN                6,91
# 4                                 NaN        NaN                8,10
# ..                                ...        ...                 ...
# 118                              6,90       9,00                6,98
# 119                              8,50       6,70                7,37
# 120                              9,00       8,70                7,69
# 121                              9,10       8,20                6,92
# 122                              6,00       7,90                7,02
#
#        Xep loai
# 0           Kha
# 1           Kha
# 2          Gioi
# 3    Trung binh
# 4          Gioi
# ..          ...
# 118  Trung binh
# 119         Kha
# 120         Kha
# 121  Trung binh
# 122         Kha
#
# [123 rows x 83 columns]

# %%
for i in df.columns:
    missing_Data=df[i].isna().sum()
    pecent=missing_Data/len(df)*100
    if pecent > 80:
        df=df.drop(i,axis=1)
    print(f"missing data is {pecent}% in colums {i}")
# Out:
# missing data is 0.0% in colums
# missing data is 0.0% in colums Kinh te vi mo
# missing data is 0.0% in colums Toan cao cap C1
# missing data is 0.0% in colums  Marketing can ban
# missing data is 0.0% in colums Ky nang giao tiep
# missing data is 0.0% in colums Giao duc quoc phong
# missing data is 65.04065040650406% in colums Ky nang ban hang
# missing data is 0.0% in colums Nhap mon nganh quan tri
# missing data is 0.0% in colums  Tin hoc MOS 1 (Windows, Word)
# missing data is 100.0% in colums Sinh hoat dau khoa
# missing data is 0.0% in colums Quan tri hoc
# missing data is 0.0% in colums  Tin hoc MOS 2 (Excel, Powerpoint)
# missing data is 0.0% in colums Tieng Anh tong quat 1
# missing data is 0.0% in colums Khoi nghiep
# missing data is 65.04065040650406% in colums Toan kinh te
# missing data is 65.04065040650406% in colums Tam li hoc khach hang
# missing data is 65.04065040650406% in colums Tu duy phan bien
# missing data is 0.0% in colums Kinh te vi mo.1
# missing data is 0.0% in colums Phap luat dai cuong
# missing data is 0.0% in colums Giao duc the chat
# missing data is 65.04065040650406% in colums Dia li kinh te Viet Nam
# missing data is 0.0% in colums Tieng Anh tong quat 2
# missing data is 65.04065040650406% in colums Thong ke kinh doanh
# missing data is 65.04065040650406% in colums  Field trip 1
# missing data is 0.0% in colums Kinh te quoc te
# missing data is 0.0% in colums Nhung nguyen li co ban cua Chu nghia Mac - Lenin
# missing data is 0.0% in colums Quan tri nguon nhan luc
# missing data is 0.0% in colums Tieng Anh giao tiep quoc te 1
# missing data is 0.0% in colums Thuong mai dien tu
# missing data is 0.0% in colums Tu tuong Ho Chi Minh
# missing data is 0.0% in colums Luat kinh doanh
# missing data is 0.0% in colums Tieng Anh giao tiep quoc te 2
# missing data is 65.04065040650406% in colums  Module 1: Phuong phap nghien cuu trong kinh doanh
# missing data is 65.04065040650406% in colums  English for Business Correspondence, Presentation and Meetings
# missing data is 65.04065040650406% in colums Giai tiep lien van hoa
# missing data is 65.04065040650406% in colums Quan li su thay doi
# missing data is 0.0% in colums Quan tri Marketing
# missing data is 0.0% in colums Quan tri tai chinh
# missing data is 0.0% in colums Duong loi cach mang cua Dang cong san Viet Nam
# missing data is 0.0% in colums Quan tri san xuat va chat luong
# missing data is 65.04065040650406% in colums Thuc hanh nghe nghiep (Professional Practice)
# missing data is 65.04065040650406% in colums  English for International Trade and Industrial Management
# missing data is 0.0% in colums Cham soc khach hang
# missing data is 0.0% in colums Nguyen ly ke toan
# missing data is 65.04065040650406% in colums Ky nang bieu dien thanh nhac
# missing data is 65.04065040650406% in colums Giao tiep da phuong tien trong kinh doanh
# missing data is 65.04065040650406% in colums  English for Service Industry
# missing data is 65.04065040650406% in colums Quan tri truyen thong tich hop
# missing data is 0.0% in colums Quan tri chien luoc
# missing data is 65.04065040650406% in colums Quan tri thuong hieu
# missing data is 65.04065040650406% in colums Chien luoc Marketing
# missing data is 65.04065040650406% in colums To chuc su kien
# missing data is 65.04065040650406% in colums Nghe thuat lanh dao
# missing data is 0.0% in colums Du an kinh doanh
# missing data is 65.04065040650406% in colums  English for the Import and Export Industry
# missing data is 65.04065040650406% in colums  Module 2:  Ban hang
# missing data is 65.04065040650406% in colums  Seminar Lap ke hoach va phat trien nghe nghiep
# missing data is 0.0% in colums Khoa luan tot nghiep
# missing data is 0.0% in colums Thuc tap tot nghiep (Intership)
# missing data is 65.04065040650406% in colums Vo thuat
# missing data is 34.959349593495936% in colums Ky nang thuyet trinh
# missing data is 34.959349593495936% in colums Xac xuat thong ke
# missing data is 34.959349593495936% in colums Qui hoach tuyen tinh
# missing data is 34.959349593495936% in colums Thong ke kinh doanh.1
# missing data is 34.959349593495936% in colums Ky nang giao tiep(HP2)
# missing data is 34.959349593495936% in colums Kinh te luong ung dung trong kinh doanh
# missing data is 34.959349593495936% in colums Tieng Anh giao tiep quoc te 2.1
# missing data is 34.959349593495936% in colums  Module 1: Phuong phap nghien cuu trong kinh doanh.1
# missing data is 34.959349593495936% in colums Ly thuyet tai chinh - tien te 1
# missing data is 34.959349593495936% in colums Tieng Anh giao tiep quoc te 3
# missing data is 34.959349593495936% in colums Tieng Anh chuyen nganh
# missing data is 34.959349593495936% in colums Tieng Anh giao tiep quoc te 4
# missing data is 34.959349593495936% in colums Tieng Anh chuyen nganh 2
# missing data is 34.959349593495936% in colums Hanh vi to chuc
# missing data is 34.959349593495936% in colums Quan tri rui ro trong kinh doanh
# missing data is 34.959349593495936% in colums Quan tri Logistics
# missing data is 34.959349593495936% in colums Quan tri kinh doanh quoc te
# missing data is 34.959349593495936% in colums  Module 2: Kinh doanh xuat nhap khau
# missing data is 34.959349593495936% in colums Tam ly hoc dai cuong
# missing data is 34.959349593495936% in colums Van tai, bao hiem van tai quoc te
# missing data is 34.959349593495936% in colums  Logistics
# missing data is 0.0% in colums Trung binh tich luy
# missing data is 0.0% in colums Xep loai

# %%
df['Xep loai'].value_counts()
# Out:
# Kha           82
# Trung binh    36
# Gioi           5
# Name: Xep loai, dtype: int64

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %%
df=df.drop(['Giao duc quoc phong','Giao duc the chat'],axis=1)

# %%
count_class0,count_class1,count_class2=df['Xep loai'].value_counts()
df_class0=df[df['Xep loai']=='Kha']
df_class1=df[df['Xep loai']=='Trung binh']
df_class2=df[df['Xep loai']=='Gioi']

df_class1_over=df_class1.sample(len(df_class0),replace=True)
df_class2_over=df_class2.sample(len(df_class0),replace=True)

df1=pd.concat([df_class0,df_class1_over,df_class2_over],axis=0)
df1=df1.iloc[:,1:]
df1=df

# %%
df1['Xep loai'].value_counts()
# Out:
# Kha           82
# Trung binh    36
# Gioi           5
# Name: Xep loai, dtype: int64

# %%
df_train=df1.iloc[:,1:-2]
result=df1.iloc[:,-1]

# %%
for col in df_train:
    df_train[col]=df_train[col].apply(lambda x:float(str(x).replace(',','.')))
for col in df_train:
    df_train[col]=df_train[col].fillna(df_train[col].mean())
# Out:
# C:\Users\tranq\AppData\Local\Temp\ipykernel_10704\167655690.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train[col]=df_train[col].apply(lambda x:float(str(x).replace(',','.')))
# C:\Users\tranq\AppData\Local\Temp\ipykernel_10704\167655690.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train[col]=df_train[col].fillna(df_train[col].mean())

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier

# %%
X_train1,X_test1,y_train1,y_test1=train_test_split(df_train,result,test_size=0.2,random_state=0)
rf = RandomForestClassifier(n_estimators=150, 
                                max_depth=10, 
                                class_weight="balanced",
                                max_features="auto")
rf.fit(X_train1,y_train1)
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
y_pred0=rf.predict(X_test1)
print(classification_report(y_test1,y_pred0))
print(accuracy_score(y_test1, y_pred0))
accurcy_rf=accuracy_score(y_test1, y_pred0)
# Out:
#               precision    recall  f1-score   support
#
#         Gioi       0.00      0.00      0.00         1
#          Kha       0.91      1.00      0.95        20
#   Trung binh       1.00      0.75      0.86         4
#
#     accuracy                           0.92        25
#    macro avg       0.64      0.58      0.60        25
# weighted avg       0.89      0.92      0.90        25
#
# 0.92
# C:\Users\tranq\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tranq\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tranq\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
sorted_idx = rf.feature_importances_.argsort()
arr=[]
for i in zip(X_train1.columns[sorted_idx], rf.feature_importances_[sorted_idx]):
    arr.append(i)
sorted_by_second = sorted(arr, key=lambda tup: tup[1], reverse=True)

# %%
a=sorted_by_second[:len(sorted_by_second)//2]
names=[]
for i in range(len(a)):
    names.append(a[i][0])
names
# Out:
# [' Tin hoc MOS 1 (Windows, Word)',
#  'Kinh te quoc te',
#  ' Tin hoc MOS 2 (Excel, Powerpoint)',
#  'Ky nang giao tiep',
#  'Toan cao cap C1',
#  'Kinh te vi mo',
#  'Tieng Anh giao tiep quoc te 2',
#  'Du an kinh doanh',
#  'Duong loi cach mang cua Dang cong san Viet Nam',
#  'Quan tri tai chinh',
#  'Quan tri Logistics',
#  'Nguyen ly ke toan',
#  'Nhap mon nganh quan tri',
#  'Khoi nghiep',
#  'Kinh te luong ung dung trong kinh doanh',
#  'Quan tri nguon nhan luc',
#  'Thuong mai dien tu',
#  'Cham soc khach hang',
#  'Kinh te vi mo.1',
#  'Quan tri hoc',
#  'Xac xuat thong ke',
#  ' Marketing can ban',
#  'Tieng Anh giao tiep quoc te 2.1',
#  'Qui hoach tuyen tinh',
#  'Thong ke kinh doanh.1',
#  'Tieng Anh tong quat 2',
#  'Quan tri san xuat va chat luong',
#  'Tam ly hoc dai cuong',
#  'Tieng Anh tong quat 1',
#  'Khoa luan tot nghiep',
#  'Van tai, bao hiem van tai quoc te',
#  'Luat kinh doanh',
#  'Tieng Anh giao tiep quoc te 1',
#  'Hanh vi to chuc',
#  'Tu tuong Ho Chi Minh',
#  'Nhung nguyen li co ban cua Chu nghia Mac - Lenin',
#  'Dia li kinh te Viet Nam',
#  'Phap luat dai cuong']

# %%
df2=df1[names]
for col in df2:
    df2[col]=df2[col].apply(lambda x:float(str(x).replace(',','.')))
for col in df2:
    df2[col]=df2[col].fillna(df2[col].mean())
df2

X_train2,X_test2,y_train2,y_test2=train_test_split(df2,result,test_size=0.2,random_state=0)

rdf = RandomForestClassifier(n_estimators=150, 
                                max_depth=10, 
                                class_weight="balanced",
                                max_features="auto")
rdf.fit(X_train2,y_train2)
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
y_pred1=rdf.predict(X_test2)
print(classification_report(y_test2,y_pred1))
print(accuracy_score(y_test2, y_pred1))
accurcy_rf_modelSelection=accuracy_score(y_test2, y_pred1)
# Out:
# C:\Users\tranq\AppData\Local\Temp\ipykernel_10704\1497257429.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[col]=df2[col].apply(lambda x:float(str(x).replace(',','.')))
# C:\Users\tranq\AppData\Local\Temp\ipykernel_10704\1497257429.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[col]=df2[col].fillna(df2[col].mean())
#               precision    recall  f1-score   support
#
#         Gioi       1.00      1.00      1.00         1
#          Kha       0.95      1.00      0.98        20
#   Trung binh       1.00      0.75      0.86         4
#
#     accuracy                           0.96        25
#    macro avg       0.98      0.92      0.94        25
# weighted avg       0.96      0.96      0.96        25
#
# 0.96

# %%
df_temp=df[names]
for col in df_temp:
    df_temp[col]=df_temp[col].apply(lambda x:float(str(x).replace(',','.')))
for col in df2:
    df_temp[col]=df_temp[col].fillna(df_temp[col].mean())
df_temp
df3=pd.concat([df_temp,df.iloc[:,-1]],axis=1)
# Out:
# C:\Users\tranq\AppData\Local\Temp\ipykernel_10704\2046318792.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp[col]=df_temp[col].apply(lambda x:float(str(x).replace(',','.')))
# C:\Users\tranq\AppData\Local\Temp\ipykernel_10704\2046318792.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp[col]=df_temp[col].fillna(df_temp[col].mean())

# %%
df3['Xep loai'].value_counts()
# Out:
# Kha           82
# Trung binh    36
# Gioi           5
# Name: Xep loai, dtype: int64

# %%
soluong = len(df3)
soluong
mang_chua_27_tong_diem = []
for i in range(len(names)):
    tong_mon = 0.0
    
    for j in range(soluong):
        tong_mon += df3.iloc[j,i]
        
    mang_chua_27_tong_diem.append(tong_mon/soluong)
tenMon=df3.columns
len(mang_chua_27_tong_diem)
# Out:
# 38

# %%
a=np.array(mang_chua_27_tong_diem)
a.sum()/(len(sorted_by_second)//2)
# Out:
# 7.143126088405926

# %%
min_27 = min(mang_chua_27_tong_diem)
max_27 = max(mang_chua_27_tong_diem)
hieu = max_27 - min_27


moc_tb = np.linspace(min_27,max_27, 7)
arr_tb =[]
for i in range(len(moc_tb)):
    arr_tb.append(moc_tb[i])


arr_dtbk = []
for j in range(1,len(arr_tb)):
    
    dtbk = (arr_tb[j-1]+ arr_tb[j])/2
    arr_dtbk.append(dtbk)

# %%
chia_deu_5_muc_kho = hieu/5

# %%
kho_5 = min_27 + 1*chia_deu_5_muc_kho
kho_4 = min_27 + 2*chia_deu_5_muc_kho
kho_3 = min_27 + 3*chia_deu_5_muc_kho
kho_2 = min_27 + 4*chia_deu_5_muc_kho
kho_1 = min_27 + 5*chia_deu_5_muc_kho

# %%
def do_kho(diem):
    if (diem>4 and diem<=4.5):
        return 4 
    elif (diem>4.5 and diem<=5.5):
        return 5
    elif (diem>5.5 and diem<=6.5):
        return 6
    elif (diem>6.5 and diem<=7.5):
        return 7
    elif (diem>7.5 and diem<=8.5):
        return 8
    elif (diem>8.5 and diem<=9.5):
        return 9
    else:
        return 10

# %%
mang_do_kho_mon = {}

for i in range(len(mang_chua_27_tong_diem)):
    x = mang_chua_27_tong_diem[i]
    s = do_kho(x)
    mang_do_kho_mon[tenMon[i]]=s
mang_do_kho_mon
# Out:
# {' Tin hoc MOS 1 (Windows, Word)': 7,
#  'Kinh te quoc te': 7,
#  ' Tin hoc MOS 2 (Excel, Powerpoint)': 7,
#  'Ky nang giao tiep': 7,
#  'Toan cao cap C1': 7,
#  'Kinh te vi mo': 7,
#  'Tieng Anh giao tiep quoc te 2': 7,
#  'Du an kinh doanh': 8,
#  'Duong loi cach mang cua Dang cong san Viet Nam': 7,
#  'Quan tri tai chinh': 8,
#  'Quan tri Logistics': 7,
#  'Nguyen ly ke toan': 7,
#  'Nhap mon nganh quan tri': 7,
#  'Khoi nghiep': 7,
#  'Kinh te luong ung dung trong kinh doanh': 7,
#  'Quan tri nguon nhan luc': 7,
#  'Thuong mai dien tu': 7,
#  'Cham soc khach hang': 7,
#  'Kinh te vi mo.1': 7,
#  'Quan tri hoc': 7,
#  'Xac xuat thong ke': 7,
#  ' Marketing can ban': 7,
#  'Tieng Anh giao tiep quoc te 2.1': 7,
#  'Qui hoach tuyen tinh': 7,
#  'Thong ke kinh doanh.1': 7,
#  'Tieng Anh tong quat 2': 7,
#  'Quan tri san xuat va chat luong': 7,
#  'Tam ly hoc dai cuong': 8,
#  'Tieng Anh tong quat 1': 7,
#  'Khoa luan tot nghiep': 8,
#  'Van tai, bao hiem van tai quoc te': 8,
#  'Luat kinh doanh': 8,
#  'Tieng Anh giao tiep quoc te 1': 7,
#  'Hanh vi to chuc': 8,
#  'Tu tuong Ho Chi Minh': 7,
#  'Nhung nguyen li co ban cua Chu nghia Mac - Lenin': 6,
#  'Dia li kinh te Viet Nam': 7,
#  'Phap luat dai cuong': 7}

# %%
def diem_tt(tenMon, diem):

    return diem*mang_do_kho_mon[tenMon],mang_do_kho_mon[tenMon]

# %%
arr_something=[]
for i in range(0,soluong):
    arr_input = df_train.iloc[i,1:-1].values
    arr_diemtt = []
    arr_diemtanggiam = []
    arr_input = list(map(lambda x:float(str(x).replace(',','.')), arr_input))

    arr_tenmon = df_train.columns
    arr_tenmon = arr_tenmon[1:-1]

    b={}
    for i in range(0,len(arr_input)):
        b[arr_tenmon[i]]=arr_input[i]
    arr_something.append(b)

# %%
def persent(diem_quakhu, diem_hientai):
    return ((diem_hientai-diem_quakhu)/(diem_hientai+diem_quakhu))*100

# %%
def tinh_diem(diem_quakhu, diem_hientai):
    return (diem_hientai+diem_quakhu)/2

# %%
arr_Check_Diem=[]
def thuc_hoc(inputt):
    for i in inputt:
        diemt=0
        doKho=0
        for j in i:
            if j in mang_do_kho_mon:
                point,dok=diem_tt(j,i.get(j))
                diemt+=point
                doKho+=dok
        arr_Check_Diem.append(diemt/doKho)
    return arr_Check_Diem

# %%
arr_diem_nl=thuc_hoc(arr_something)

# %%
df_dl=pd.DataFrame(np.stack((arr_diem_nl,df['Xep loai'])))

# %%
df_dl=df_dl.T

# %%
df_hoiQui=pd.DataFrame(np.stack((arr_diem_nl,df['Trung binh tich luy'])))
df_hoiQui=df_hoiQui.T

# %%
from sklearn.datasets import make_multilabel_classification
import numpy as np
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
result=le.fit_transform(df_dl[1])
result=np.array(result.astype('float'))
train=df_dl[0]
train=np.array(train.astype('float'))

from sklearn.model_selection import train_test_split

X_train3,X_test3,y_train3,y_test3=train_test_split(train,result,test_size=0.2,random_state=0)

clf1 = RandomForestClassifier(n_estimators=150, 
                                max_depth=10,  
                                class_weight="balanced",
                                max_features="auto")

clf1.fit(X_train3.reshape(-1, 1), y_train3)
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
pred2 = clf1.predict(X_test3.reshape(-1, 1))
print(classification_report(y_test3,pred2))
print(accuracy_score(y_test3, pred2))
accurcy_special=accuracy_score(y_test3, pred2)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       0.95      0.95      0.95        20
#          2.0       0.75      0.75      0.75         4
#
#     accuracy                           0.92        25
#    macro avg       0.90      0.90      0.90        25
# weighted avg       0.92      0.92      0.92        25
#
# 0.92

# %%
df_test=pd.read_csv('test.csv')
df_test
# Out:
#                  Kinh te quoc te Toan cao cap C1  Sinh hoat dau khoa  \
# 0  Diem tong ket            6,10            5,70                 NaN
# 1  Diem tong ket            6,60            6,90                 NaN
# 2  Diem tong ket            8,20            7,40                 NaN
# 3  Diem tong ket            7,90            5,70                 NaN
# 4  Diem tong ket            8,00            6,40                 NaN
# 5  Diem tong ket            8,70            6,70                 NaN
# 6  Diem tong ket            9,20            8,60                 NaN
# 7  Diem tong ket            6,60            8,50                 NaN
# 8  Diem tong ket            6,60            8,50                 NaN
#
#   Quan tri hoc Ky nang thuyet trinh Nhap mon nganh quan tri  \
# 0         6,40                 7,80                    7,90
# 1         5,90                 8,90                    7,30
# 2         8,30                10,00                    8,00
# 3         5,40                 7,10                    5,80
# 4         9,10                 5,90                    6,90
# 5        10,00                 7,00                    5,60
# 6         7,60                 9,50                    7,90
# 7         7,10                 9,90                    7,40
# 8         7,10                 9,90                    7,40
#
#    Marketing can ban Ky nang giao tiep Giao duc quoc phong  ...  \
# 0               6,20              9,50                7,00  ...
# 1               7,00              5,20                7,20  ...
# 2               7,70              6,90                8,00  ...
# 3               7,00              6,00                6,00  ...
# 4               4,80              6,00                5,60  ...
# 5               6,80              6,00                4,80  ...
# 6               7,70              5,80                7,00  ...
# 7               7,20              5,90                7,00  ...
# 8               7,20              5,90                7,00  ...
#
#   Tu tuong Ho Chi Minh Qui hoach tuyen tinh Nguyen ly ke toan  \
# 0                 9,10                 8,10              6,50
# 1                 8,10                 7,70              7,00
# 2                 7,60                 8,00              7,50
# 3                 8,30                 7,00              6,30
# 4                 8,30                 5,80              7,50
# 5                 8,50                 8,20              6,80
# 6                 8,50                 6,70              9,50
# 7                 8,00                 7,30              6,00
# 8                 8,00                 7,30              6,00
#
#   Chuyen de tot nghiep To chuc su kien Thanh toan quoc te  \
# 0                 7,50            7,80               9,40
# 1                 8,80            8,00               8,00
# 2                 8,00            7,40               7,50
# 3                 7,50            6,20               7,00
# 4                 8,20            6,50               8,10
# 5                 6,70            5,60               8,50
# 6                 8,00            8,00               7,90
# 7                 7,40            8,50               8,00
# 8                 7,40            8,50               8,00
#
#   Quan tri thuong hieu Quan tri rui ro trong kinh doanh Trung binh tich luy  \
# 0                 8,20                             8,00                7,01
# 1                 9,00                             8,80                7,22
# 2                 7,50                             9,00                7,79
# 3                 8,50                             7,60                6,59
# 4                 8,90                             7,30                6,74
# 5                 8,80                             9,10                6,93
# 6                 7,00                             7,70                7,39
# 7                 8,80                             6,80                7,34
# 8                 8,80                             6,80                6,83
#
#      Xep loai
# 0         Kha
# 1         Kha
# 2         Kha
# 3  Trung binh
# 4  Trung binh
# 5  Trung binh
# 6         Kha
# 7         Kha
# 8  Trung binh
#
# [9 rows x 58 columns]

# %%
for i in df_test.columns:
    missing_Data=df_test[i].isna().sum()
    pecent=missing_Data/len(df_test)*100
    if pecent > 80:
        df_test=df_test.drop(i,axis=1)

# %%
df_test=df_test.drop(['Giao duc quoc phong','Giao duc the chat'],axis=1)

# %%
a=df.iloc[8,1:9]

# %%
arr_tenmon = df_test.columns
arr_tenmon = arr_tenmon[1:-1]

a=a.apply(lambda x:float(str(x).replace(',','.')))
a=a.astype('float')
print(a)
# Out:
# Kinh te vi mo                     6.5
# Toan cao cap C1                   7.0
#  Marketing can ban                5.6
# Ky nang giao tiep                 9.7
# Ky nang ban hang                  5.4
# Nhap mon nganh quan tri           6.5
#  Tin hoc MOS 1 (Windows, Word)    6.3
# Quan tri hoc                      4.7
# Name: 8, dtype: float64

# %%
b={}
arr_input_test =[]
for i in range(0,len(a)):
    b[arr_tenmon[i]]=a[i]
arr_input_test.append(b)

arr_Check_Diem=[]

def thuc_hoct(inputt):
    diemt=0.0
    doKho=0.0
    for j in inputt:
        print(j)
        if j in mang_do_kho_mon:
            point,dok=diem_tt(j,i.get(j))
            diemt+=point
            doKho+=dok
    arr_Check_Diem.append(diemt/doKho)
    print('điểm và độ khó: ',diemt/doKho)
    return arr_Check_Diem

arr_diem=np.array(thuc_hoc(arr_input_test))
print(clf1.predict(arr_diem.reshape(-1,1)))
# Out:
# [2.]

# %%
names=['radom forest','rf+ model selection','radomforest special']
models=[]
models.append(accurcy_rf)
models.append(accurcy_rf_modelSelection)
models.append(accurcy_special)

df = pd.DataFrame({'':models}, index=names)
ax = df.plot.bar()
ax.bar_label(ax.containers[0])

plt.title('biểu đồ độ chính xác của mô hình')
# Out:
# Text(0.5, 1.0, 'biểu đồ độ chính xác của mô hình')

# %%
from sklearn.linear_model import LinearRegression

result=df_hoiQui[1]
result=result.apply(lambda x:float(str(x).replace(',','.')))
result=np.array(result.astype('float'))
train=df_hoiQui[0]
train=np.array(train.astype('float'))

from sklearn.model_selection import train_test_split

X_train4,X_test4,y_train4,y_test4=train_test_split(train,result,test_size=0.2,random_state=0)

model=LinearRegression()

model.fit(X_train4.reshape(-1,1),y_train4)
# Out:
# LinearRegression()

# %%
import sklearn

y_pred=model.predict(X_test4.reshape(-1,1))
mse = sklearn.metrics.mean_squared_error(y_test4, y_pred)
print(f'trung bình lỗi là: {mse} ')
plt.scatter(X_test4, y_test4, color="black")
plt.plot(X_test4, y_pred, color="blue", linewidth=3)
# Out:
# trung bình lỗi là: 0.023511958307329786
